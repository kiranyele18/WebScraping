# %%
import sys
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
try:
    pages = requests.get('https://www.cricbuzz.com/') #this might throws an exception if something goes
    
except Exception as e: #this describes what to do if an exception is thrown 
    error_type,error_obj,error_info = sys.exc_info() #get the exception information
    print('ERROR FOR LINK: ', url) #print the link that cause problem
    print(error_type,'Line: ',error_info.tb_lineno) #print error info and line that threw the exception
    
    #ignore this page.Abandon this and go back.
    
time.sleep(2)
soup=BeautifulSoup(pages.text,'html.parser')
links = soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
pages
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">Broad, Woakes, Wood, Robinson &amp; Leach will fight for bowling spots as England name 12-man squad </div>,
#  <div class="cb-nws-intr">Sisanda Magala and Ryan Rickelton received maiden Test call-ups</div>,
#  <div class="cb-nws-intr">Both batters struck half-centuries after the visitors lost two quick wickets on day four</div>,
#  <div class="cb-nws-intr">India beat NZ by 372 runs to take series 1-0</div>,
#  <div class="cb-nws-intr">Haseeb Hameed has endured more than his share of challenges for a player of his age. Now, as he prepares for the adventure of his first Ashes series in Australia, he talks about how he's back where he should be, enjoying the game</div>,
#  <div class="cb-nws-intr">Even as New Zealand had a forgettable day on the field, the left-arm spinner made a place for himself in an elite list of cricketers</div>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# Broad, Woakes, Wood, Robinson & Leach will fight for bowling spots as England name 12-man squad
#
#
# Sisanda Magala and Ryan Rickelton received maiden Test call-ups
#
#
# Both batters struck half-centuries after the visitors lost two quick wickets on day four
#
#
# India beat NZ by 372 runs to take series 1-0
#
#
# Haseeb Hameed has endured more than his share of challenges for a player of his age. Now, as he prepares for the adventure of his first Ashes series in Australia, he talks about how he's back where he should be, enjoying the game
#
#
# Even as New Zealand had a forgettable day on the field, the left-arm spinner made a place for himself in an elite list of cricketers
#
#
# The team returned from Zimbabwe after the ICC Women's World Cup qualifiers ended abruptly due to the outbreak of the Omnicron variant of COVID-19
#
#
# The allrounder suffered a stress fracture to her right foot during the recently-concluded WBBL
#
#
# ...
